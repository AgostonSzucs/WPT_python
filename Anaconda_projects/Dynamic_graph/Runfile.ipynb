# %%
# %run pyqt_test.py

# %%
# %run graph.py

# %%
# %run serial_test.py
# Out:
# empty line
# dyn raw
# empty line
# Value in hex
#
# 83571556569E79563412C28DEC88AF2267541111
#
# No change!
#
# empty line
# empty line
# Urect:5715
#
# Irect:5656
#
# Uout:9E79
#
# Iout:5634
#
# Temp:12
#
# Urectmin:C28D
#
# Urectset:EC88
#
# Urecthigh:AF22
#
# Alert:67
#
# dyn raw
# empty line
# Value in hex
#
# 83571556569E79563412C28DEC88AF2267541111
#
# No change!
#
# empty line
# empty line
# Urect:5715
#
# Irect:5656
#
# Uout:9E79
#
# Iout:5634
#
# Temp:12
#
# Urectmin:C28D
#
# Urectset:EC88
#
# Urecthigh:AF22
#
# Alert:67
#
# dyn raw
# empty line
# Value in hex
#
# 83571556569E79563412C28DEC88AF2267541111
#
# No change!
#
# empty line
# empty line
# Urect:5715
#
# Irect:5656
#
# Uout:9E79
#
# Iout:5634
#
# Temp:12
#
# Urectmin:C28D
#
# Urectset:EC88
#
# Urecthigh:AF22
#
# Alert:67
#
# dyn raw
# empty line
# Value in hex
#
# 83571556569E79573412C28DEC88AF2267541111
#
# Changed!
#
# empty line
# empty line
# Urect:5715
#
# Irect:5656
#
# Uout:9E79
#
# Iout:5734
#
# Temp:12
#
# ...

# %%
# %run file_read.py
# Out:
# dynamic\Alert.txt
# [['17582982', '17583182', '17583382', '17583582', '17583782', '17583982', '17584182', '17584382', '17584582', '17584782', '17584982', '17585182', '17585382', '17585582', '17585782', '17585982', '17590182', '17590382', '17590582', '17590782', '']]
#
#
#
# dynamic\Iout.txt
# [['17582982', '17583182', '17583382', '17583582', '17583782', '17583982', '17584182', '17584382', '17584582', '17584782', '17584982', '17585182', '17585382', '17585582', '17585782', '17585982', '17590182', '17590382', '17590582', '17590782', ''], ['175827714F', '175829714F', '175831714F', '175833714F', '175835714F', '175837714F', '175839714F', '175841714F', '175843714F', '175845714F', '175847714F', '175849714F', '175851714F', '175853714F', '175855714F', '175857714F', '175859714F', '175901714F', '175903714F', '175905714F', '175907714F', '']]
#
#
#
# dynamic\Irect.txt
# ...

# %%
qtcreator
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-c5be80c3b773> in <module>()
# ----> 1 qtcreator
#
# NameError: name 'qtcreator' is not defined
